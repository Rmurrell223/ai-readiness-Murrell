# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Muffm\anaconda3\python.exe

# %%
def calculate_stats(numbers):
    mean_val = sum(numbers) / len(numbers)
    max_val = max(numbers)
    return mean_val, max_val

my_list = [10, 25, 42, 7, 19]
print(calculate_stats(my_list))
# Out:
# (20.6, 42)

# %% [markdown]
# VS Code runs the full scripts in the command line interface, whereas Jupyter executes the code cell by cell. I find Jupyter being alot more user friendly, however i do believe VS code may appear daunting and intimidating for first time users, I believe once the user gains understanding of the tool it can be more beneficial.
